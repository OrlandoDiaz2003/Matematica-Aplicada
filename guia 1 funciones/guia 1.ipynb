# %% [markdown]
# # Problema 1

# %% [markdown]
# Una red transmite datos a $100$ megabits por segundo. Crea una función utilizando *Python* que permita calcular la cantidad de datos transmitidos en una cierta cantidad de tiempo (en segundos). Luego utiliza la función y calcula cuántos datos se transmiten en:
#
# * $45$ segundos
# * $1,5$ minutos
# * $1$ hora

# %%
'''
x = variable independiente tiempo, en segundos
y = variable dependiente megabits
'''

def f(t):
    return 100 * t

print(f"en 45 segundos se transminte {f(45)} megabits")

print(f"en 1,5 minutos se transmite {f(90)} megabits")

print(f"en 1 hora se transmiten {f(3600)} megabit")
# Out:
# en 45 segundos se transminte 4500 megabits
# en 1,5 minutos se transmite 9000 megabits
# en 1 hora se transmiten 360000 megabit

# %% [markdown]
# Utilizando la función definida en el problema $1$, genera un listado que muestre los datos transmitidos para tiempos desde $0$ hasta $1.000$ segundos con incrementos de $100$ segundos.

# %%
'''
0 = inicio de la iteracion

11000 = hasta donde va llegar

100 = saltos en la iteracion
'''

for i in range(0,1100,100):
    print(f"en {i} segundos se transmiten {f(i)} megabits")
# Out:
# en 0 segundos se transmiten 0 megabits
# en 100 segundos se transmiten 10000 megabits
# en 200 segundos se transmiten 20000 megabits
# en 300 segundos se transmiten 30000 megabits
# en 400 segundos se transmiten 40000 megabits
# en 500 segundos se transmiten 50000 megabits
# en 600 segundos se transmiten 60000 megabits
# en 700 segundos se transmiten 70000 megabits
# en 800 segundos se transmiten 80000 megabits
# en 900 segundos se transmiten 90000 megabits
# en 1000 segundos se transmiten 100000 megabits

# %% [markdown]
# # Problema 3

# %% [markdown]
# La **latencia** de una red corresponde al tiempo que tarda un paquete de datos en viajar desde el punto de origen al destino. En otras palabras, es el tiempo que transcurre desde que se envía una solicitud de un dispositivo hasta que se recibe una respuesta del servidor u otro dispositivo.
#
# La latencia puede verse afectada por la velocidad de transmisión de los datos a través de los cables o conexiones inalámbricas, la distancia física entre los dispositivos, el tiempo que tarda un computador en procesar o reenviar los datos, etc.
#
# En redes de comunicación, como las videoconferencias, juegos en línea y transmisión de datos en tiempo real, es deseable una baja latencia, de lo contrario pueden existir retrasos en la comunicación y afectar negativamente la experiencia del usuario.

# %% [markdown]
# Según el contexto mencionado, crea una función en *Python* que permita calcular la **latencia real** de una red dada una latencia estimada. Suponga que la latencia real es un $20\%$ mayor a la latencia estimada.
#
# Calcule la latencia real para una latencia estimada de:
#
# a)   $200$ milisegundos.
#
# b)   $149$ milisegundos.
#
# c)   $74$ milisegundos.

# %%
'''
X = Variable independiente latencia real
Y = Variable dependiente latencia estimada 

latencia real es un 20% mayor

latencia real = latencia estimada * (tiempo * 120/100)

'''

def f(l):
    return l * 1.20

print(f"La latencia real para una latencia estimada de 200 ms seria de: {f(200):.1f} ms")
print(f"la latencia real para una latencia estimada de 149 ms seria de: {f(149):.1f} ms")
print(f"La latencia real para una latencia estimada de 74 ms seria de: {f(74):.1f} ms")
# Out:
# La latencia real para una latencia estimada de 200 ms seria de: 240.0 ms
# la latencia real para una latencia estimada de 149 ms seria de: 178.8 ms
# La latencia real para una latencia estimada de 74 ms seria de: 88.8 ms

# %% [markdown]
# # Problema 4

# %% [markdown]
# Como parte de un proyecto de mejora, en el año $2021$ se instaló un cable de fibra óptica que une España con EEUU. El cable tiene un largo de $6.600$ $km$ y fue colocado por un barco a una velocidad de $1,85$ $km/h$.
#
#
#
# 1.   Determine la forma algebraica de la función que permite determinar el largo del cable instalado (en km) a partir del tiempo transcurrido (en horas). Utilice la instrucción *def* para definir la función en *Python*.
# 2.   Defina variable dependiente e independiente, indicando unidad de medida.
# 3.   Determine el dominio contextualizado de la función.
# 4.   Grafique la función utilizando la biblioteca *Matplotlib* considerando el dominio contextualizado.
# 5.   ¿Cuántos metros de cable se instalaron al transcurrir $148$ horas? ¿Y transcurridas $2.300$ horas?
# 6.   Si se han instalado $3.480$ kilometros de cable, ¿cuántas horas llevan de trabajo?
# 7.   ¿Cuánto tiempo transcurrió para que se completara la obra?

# %%
"1."
def l(t):
    return t * 1.85

'''
2. Variable independiente = el tiempo en horas 
   Varaible dependiente = longitud
'''
'''
El dominio contextualizado

1.85t= 6600
t= 6600 / 1.85
t= 3567.6 horas

[0 ; 3567.6]
'''

'''Grafico '''
import matplotlib.pyplot as plt
import numpy as np

T= np.arange(0,3570, 1)

plt.plot(T, l(T), label = "cable")

plt.title("Relacion entre longitud del cable y el tiempo")

plt.xlabel("Tiempo en horas")

plt.ylabel("longitud del cable en km")

plt.legend()

plt.grid(True)

plt.show()

# %%
'''4.'''
def l(t):
    return t * 1.85
print(f"En 148 horas se instalan {l(148)} km de cable")

print(f"En 2300 horas se instalan {l(2300)} km de cable")

t= 3480 / 1.85
print(f"instalados 3480 km de cables han transcurrido {t:.1f} horas ")
# Out:
# En 148 horas se instalan 273.8 km de cable
# En 2300 horas se instalan 4255.0 km de cable
# instalados 3480 km de cables han transcurrido 1881.1 horas

# %% [markdown]
# # Problema 5

# %% [markdown]
# Un turista ha llegado a Santiago y desea conocer algunos lugares de la ciudad. Ha decidido visitar el Palacio de la Moneda y desde ahí trasladarse al centro comercial "Costanera Center", utilizando algún medio de transporte que ofrece la ciudad.
#
# Si se traslada en metro deberá abordar en estación La Moneda y bajar en la estación Tobalaba ($9$ estaciones). La función $f(t)$ permite calcular la distancia recorrida utilizando el metro (en kilómetros) transcurridos $t$ minutos.
#
# $$f(t) = 0,4t$$
#
# Si se traslada en bus, el turista podrá observar la ciudad y otros atractivos en su viaje. La función $g(t)$ permite calcular la distancia recorrida en bus (en kilómetros) transcurridos $t$ minutos.
#
# $$g(t) = 0,3t$$
#
# Según la información anterior:
#
# 1. Grafique ambas funciones, indicando el nombre de cada eje junto con su unidad de medida. Para realizar el gráfico utilice la biblioteca *Matplotlib*.
# 2.  Si se sabe que el metro se demora $1,2$ minutos en llegar desde una estación a otra y espera $30$ segundos en cada estación, indique el dominio contextualizado para $f(t)$.
# 3. Mediante análisis gráfico, indique cuál medio de transporte es más conveniente en términos de tiempo, para el turista. Justifique.
# 4.  Si se sabe que desde estación La Moneda hasta Tobalaba son aproximadamente $6$ kilómetros ¿cuántos tiempo tardará el turista en llegar a su destino con cada una de las opciones?

# %%
import matplotlib.pyplot as plt
import numpy as np

'''
variable(x) independiente: tiempo en minutos

variable(y) dependiente: distancia recorrida en km

'''
def f(t):
    return 0.4 * t

def g(t):
    return 0.3 * t 
'''
1.Grafico de las dos funciones

'''
t = np.arange(0, 15, 1)

plt.plot(t,f(t), label = "metro")
plt.plot(t, g(t), label = "bus")

plt.title("Relacion entre la distancia recorrida por el tiempo")
plt.xlabel("Tiempo en minutos")
plt.ylabel("Distancia en km")
plt.legend()
plt.grid(True)

plt.show()

'''
2. Dominio contextualizado

el dominio contextualizado

[0 ; 14.7 ]

'''
print(f"El tiempo que tardas en llegar desde la moneda a tobalada es en bus {6/0.4} y en metro {6/0.3} por lo que es mejor en bus")
# Out:
# El tiempo que tardas en llegar desde la moneda a tobalada es en bus 15.0 y en metro 20.0 por lo que es mejor en bus

# %% [markdown]
# # Problema 6

# %% [markdown]
# La temperatura de un servidor (en °C) puede ser modelada mediante la función
#
# $$T(t) = -0,5 t^{2} + 3 t + 20$$
#
# donde $t$ corresponde al tiempo transcurrido (en horas) en un día laboral. Considere que la jornada laboral comienza a las 08:00 horas y termina a las 17:00 horas.
#
# 1.  Defina variable dependiente e independiente, indicando unidad de medida.
# 2.  Determine el dominio contextualizado del problema.
# 3.  Grafique la función utilizando *Python*.
# 4.  Mediante un análisis gráfico, estime cuándo el servidor alcanza la máxima temperatura y calcule cuánto es.
# 5.  Determine la temperatura del servidor a las 13:00 horas y al finalizar la jornada laboral.

# %% [markdown]
# 1. Variable independiente (x): tiempo en horas
#    Variable dependiente (y): temperatura en C°
#
# 2. Dominio contextualizado: [0 ; 8]

# %%
import matplotlib.pyplot as plt 
import numpy as np

def T(t):
    return -0.5*t**2 + 3*t + 20

t = np.arange(0,10,1)

plt.plot(t,T(t), label = "Temperatura en C°")

plt.title("Relacion entre la temperatura y el tiempo")
plt.xlabel("Tiempo en horas")
plt.ylabel("Grados en C°")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 4. La temperatura maxima es de 24 aproximadamente y llega a esta temperatura a las 3 horas proximadamente por lo que seria entre las 11 - 12 horas del dia

# %%
print(f"A las 13:00 la temperatura es de {T(5)} grados celsius y al finalizar la jornada seria de {T(8)}")
# Out:
# A las 13:00 la temperatura es de 22.5 grados celsius y al finalizar la jornada seria de 12.0

# %% [markdown]
# # Problema 7

# %% [markdown]
# El número de usuarios de una red social se puede modelar mediante la función:
#
# $$U(t) = \frac{1.000}{1+9e^{-0.5t}}$$
#
# donde $t$ corresponde al tiempo transcurrido en meses.
#
# 1.  Defina variable dependiente e independiente, indicando unidad de medida.
# 2.  Determine la cantidad de usuarios transcurridos $12$ meses.
# 3.  Grafique la función, utilizando la librería *Matplotlib*, para los primeros dos años de funcionamiento.
# 4.  ¿Cuánto tiempo debe pasar para que la red social llegue a $800$ usuarios?

# %% [markdown]
# 1. Variable independiente: tiempo en meses
#
#    Variable dependiente: Usuarios en unidades

# %%
'''2.Usuarios en 12  meses'''
import matplotlib.pyplot as plt
import numpy as np

def U(t):
    return 1000 / (1 + 9*(np.exp(-0.5*t)))

print(f"Transcurridos 12 meses la cantidad de usuarios son {U(12):.0f}")
# Out:
# Transcurridos 12 meses la cantidad de usuarios son 978

# %%
'''3.grafico de la funcion'''
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0,24,1)

plt.plot(t, U(t), label = "Usuarios")
plt.title("Relacion entre la cantidad de usuarios y el tiempo")
plt.xlabel("tiempo en meses")
plt.ylabel("cantidad de usuarios en unidades")

plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
from scipy.optimize import fsolve

def u(t):
    return 1000 / (1 + 9*(np.exp(-0.5*t))) - 800

t = np.linspace (0, 25, 1)

solucion = fsolve(u,t)

print(f"La cantidad de meses son {solucion[0]:.0f} la red tiene 800 usuarios")
# Out:
# La cantidad de meses son 7 la red tiene 800 usuarios

# %% [markdown]
# # Problema 8

# %% [markdown]
# El tiempo de ejecución de un algoritmo de ordenación (en segundos) se puede modelar mediante la función:
#
# $$A(n) = 0,01n^{2} + 0,5n + 2$$
#
# donde $n$ corresponde a la cantidad de elementos a ordenar. El algoritmo funciona desde las 23:00 horas hasta las 06:00 horas y debe ordenar $1.562$ elementos.
#
# 1. Defina variable dependiente e independiente, indicando unidad de medida.
# 2. Determine el dominio contextualizado de la función.
# 3. Determine el tiempo de ejecución para ordenar $1.200$ elementos.
# 4. Grafique, utilizando la biblioteca *Matplotlib*, la función $A(n)$.
# 5. ¿Cuántos elementos ordena luego de $6$ horas de funcionamiento?

# %% [markdown]
# Desarollo
#
# 1. Variable independiente: n elementos a ordenar en unidades
#
#    Variable dependiente: tiempo en segundos

# %% [markdown]
# 2. El dominio contextualizado es [0 ; 1562]

# %% [markdown]
# 3. Determinar tiempo de ejecucion 1200 elementos

# %%
def A(n):
    return 0.01*n**2 + 0.5*n + 2

print(f"El tiempo de ejecucion para odernar 1200 elementos es {A(1200):.0f} segundos")
# Out:
# El tiempo de ejecucion para odernar 1200 elementos es 15002 segundos

# %% [markdown]
# 4.Grafico

# %%
import matplotlib.pyplot as plt
import numpy as np

n = np.arange(0,1570,1)

plt.plot(n, A(n), label= "Tiempo de ejeccucion")
plt.title("Relacion tiempo y ejeccucion de algoritmo")
plt.xlabel("Elementos ordenados")
plt.ylabel("Tiempo en segundos")
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
from scipy.optimize import fsolve
def A(n):
    return 0.01*n**2+0.5*n+2 - 21600

n = np.linspace(0,1560,1)

solucion = fsolve(A,n)

print(f"si la cantida de horas son 6 el algoritmo ha ordenado {solucion[0]:.0f} elementos")
# Out:
# si la cantida de horas son 6 el algoritmo ha ordenado 1445 elementos

# %% [markdown]
# # Problema 9

# %% [markdown]
# El consumo de energía (en $kWh$) de un *Data Center* puede ser modelado por la función:
#
#  $$E(t) = 50\cdot \log(t + 1) + 200$$
#
# donde $t$ corresponde al tiempo (en horas) desde el inicio del monitoreo.
#
# 1. Defina variable dependiente e independiente, indicando unidad de medida.
# 2. Determine el consumo de energía del *Data Center* después de $5$ horas.
# 3. ¿Luego de cuántas horas el consumo será de $350$ kWh?
# 4. Grafique, utilizando la biblioteca *Matplotlib*, la función $E(t)$.

# %% [markdown]
# Desarollo
#
# 1. Variable independiente: tiempo en horas
#
#    Varaible depedendiente: consumo de energia eb kWh

# %% [markdown]
# 2. Consumo de energia despues de 5 horas

# %%
def E(t):
    return 50* np.log(t+1) + 200

print(f"El consumo de energia de un data center despues de 5 horas seria {E(5):.1f} kWh")
# Out:
# El consumo de energia de un data center despues de 5 horas seria 289.6 kWh

# %% [markdown]
# 3. Horas despues de 350 kWh consumidos

# %%
import numpy as np
from scipy.optimize import fsolve

def E(t):
    return 50* np.log(t+1) + 200 - 350

t = np.linspace(0,350,1)

solucion = fsolve(E, n)

print(f"cuando se consuman 350 kWh habran pasado {solucion[0]:.0f} horas")
# Out:
# cuando se consuman 350 kWh habran pasado 19 horas

# %% [markdown]
# 4. Grafico de la funcion

# %%
import matplotlib.pyplot as plt
import numpy as np

def E(t):
    return 50* np.log(t+1) + 200

t = np.arange(0,25, 1)

plt.plot (t,E(t), label = "consumo de energia")
plt.title("Relacion consumo de energia y el tiempo")
plt.xlabel("Tiempo en horas")
plt.ylabel("Energia en kWh")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Problema 10

# %% [markdown]
# En gestión de proyectos, es crucial entender cómo se distribuye la carga de trabajo a lo largo del tiempo para planificar recursos, tiempo y esfuerzos de manera eficiente. Un fenómeno común es la disminución exponencial de la carga de trabajo, donde el esfuerzo requerido es mayor al inicio del proyecto y disminuye gradualmente a medida que se completan las tareas principales.
#
# Esta disminución exponencial puede modelarse matemáticamente para predecir y gestionar el trabajo de manera efectiva.
#
# <br>
#
# Un estudio sobre gestión de proyectos sostiene que la carga de trabajo en un proyecto (en porcentaje) puede ser modelada por la función:
#
# $$W(t) = 100e^{-0.1t}$$
#
# donde $t$ corresponde al tiempo transcurrido (en semanas) desde el inicio del proyecto.
#
# 1. Defina variable dependiente e independiente, indicando unidad de medida.
# 2. Determine la carga de trabajo al inicio del proyecto.
# 3. ¿Cuál será la carga de trabajo luego de transcurridas $4$ semanas desde el inicio del proyecto?
# 4. Si el proyecto duró $12$ semanas, ¿es correcto afirmar que la carga de trabajo llegó al $20\%$?
# 5. ¿Cuántas semanas han pasado desde el inicio del proyecto para que la carga de trabajo sea de $55\%$?
# 6. Utilizando *Matplotlib*, grafique la función considerando un tiempo máximo de $12$ semanas.

# %% [markdown]
# Desarollo
#
# 1. Variable independiente: Carga de trabajo en porcentaje
#
#    Variable dependiente: tiempo en semanas

# %% [markdown]
# 2. Carga de trabajo al inicio del proyecto

# %%
import numpy as np

def W(t):
    return 100*np.exp(-0.1*t)

print(f"La carga de trabajo al inicio del proyecto en la semana 1 seria del {W(1):.2f} %")
# Out:
# La carga de trabajo al inicio del proyecto en la semana 1 seria del 90.48 %

# %% [markdown]
# 3. Carga del trabajo despues de 4 semanas

# %%
import numpy as np

def W(t):
    return 100*np.exp(-0.1*t)
print(f"La carga de trabajo transcurridas 4 semana seria de {W(4):.2f} %")
# Out:
# La carga de trabajo transcurridas 4 semana seria de 67.03 %

# %% [markdown]
# 4. Carga de trabajo en un proyecto de 12 semanas

# %%
import numpy as np

def W(t):
    return 100*np.exp(-0.1*t)
print(f"la carga de trabajo de un proyecto de 12 semanas llego al {W(12):.2f}%")
# Out:
# la carga de trabajo de un proyecto de 12 semanas llego al 30.12%

# %% [markdown]
# No llega al 20%

# %% [markdown]
# 5. Cuantas semanas han pasado para que la carga sea de 55%?

# %%
import numpy as np
from scipy.optimize import fsolve

def W(t):
    return 100*np.exp(-0.1*t) - 55

t = np.linspace(0, 55,1)

solucion = fsolve(W, t)

print(f"cuando la carga de trabajo sea del 55 % habran pasado {solucion[0]:.2f} semanas")
# Out:
# cuando la carga de trabajo sea del 55 % habran pasado 5.98 semanas

# %%
import matplotlib.pyplot as plt
import numpy as np

def W(t):
    return 100*np.exp(-0.1*t)

t = np.arange(0, 12 ,1)

plt.plot(t, W(t), label= "Carga de trabajo")
plt.title("Relacion entre carga de trabajo y el tiempo")
plt.xlabel("tiempo en semanas")
plt.ylabel("Cargade trabajo de porcentaje")
plt.legend()
plt.grid(True)
plt.show()
